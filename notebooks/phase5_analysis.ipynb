# %%
# Automatically locate the project's root directory
from crispdm.common.path_service_common import find_project_root

# Data manipulation and analysis using DataFrames
import pandas as pd

# Statistical data visualization built on top of matplotlib
import seaborn as sns

# Parsing and handling JSON data structures
import json

# Creating static, animated, and interactive visualizations
import matplotlib.pyplot as plt

# Numerical computing and support for large, multi-dimensional arrays
import numpy as np

# Fitting and working with statistical distributions (Normal, Skew-Normal, Gamma)
from scipy.stats import norm, skewnorm, gamma

# Object-oriented file system paths management
from pathlib import Path

from IPython.display import display

# Reading and writing YAML configuration files
import yaml

import matplotlib.patches as patches

# %%
# 1. Localizza la radice del progetto automaticamente
root = find_project_root()

# 2. Definisci il percorso verso la cartella di output (la base dei 'runs')
# l'ultima esecuzione o una specifica
run_id = "20260701_105328" # O l'ID che sto analizzando
base_run_dir = root / "outputs" / "runs" / "clustering" / "ms_sec_inc_pre" / run_id

# Definire il percorso di "base fase" per evitare hardcode in tutto il notebook
base_phase_path = base_run_dir / "phase5_evaluation_and_interpretation"

# %%
# =============================================================================
# SCRIPT DI DIAGNOSTICA: FASE 5.2 (CONFRONTO MATRICI K-MEANS vs DBSCAN)
# =============================================================================
# Descrizione:
# Questo script risponde al requisito del professore confrontando le matrici
# di confusione generate da K-Means e DBSCAN per valutarne le differenze.
# =============================================================================

import pandas as pd
import json
import matplotlib.pyplot as plt
import seaborn as sns
from pathlib import Path

# =============================================================================
# DEFINIZIONE DEI PERCORSI (Adatta base_run_dir al tuo ambiente)
# =============================================================================
# base_run_dir = Path("percorso/alla/run/principale")
base_phase5_path = base_run_dir / "phase5_evaluation_and_interpretation"

path_cm_kmeans = base_phase5_path / "5.2.business_evaluation.confusion_matrix.kmeans_n2.json"
path_cm_dbscan = base_phase5_path / "5.2.business_evaluation.confusion_matrix.dbscan_collapsed.json"

out_img_path = root / "notebooks" / "out"
out_img_path.mkdir(parents=True, exist_ok=True)

# =============================================================================
# 1. FASE DI INPUT: Caricamento delle Matrici di Confusione
# =============================================================================
def carica_matrice(path_json):
    if not path_json.exists():
        print(f"⚠️ File non trovato: {path_json}")
        return None
    with open(path_json, 'r', encoding='utf-8') as f:
        data = json.load(f)
        # Assumiamo che il JSON contenga la matrice sotto la chiave "matrix" o "confusion_matrix"
        # Se il JSON è direttamente un dizionario, passiamo quello.
        matrix_data = data.get("matrix", data)
        return pd.DataFrame(matrix_data)

print("📥 [INPUT] Caricamento delle matrici di confusione...")
df_kmeans = carica_matrice(path_cm_kmeans)
df_dbscan = carica_matrice(path_cm_dbscan)

# =============================================================================
# 2. FASE DI LOGICA: Allineamento Strutturale
# =============================================================================
print("🧠 [LOGICA] Preparazione dei dati per il confronto visivo...")
# Invertiamo l'asse Y per far combaciare la visualizzazione standard delle matrici
if df_kmeans is not None:
    df_kmeans = df_kmeans.sort_index(ascending=False)
if df_dbscan is not None:
    df_dbscan = df_dbscan.sort_index(ascending=False)

# =============================================================================
# 3. FASE DI DISEGNO: Plot Affiancato (Side-by-Side)
# =============================================================================
if df_kmeans is not None and df_dbscan is not None:
    fig, axes = plt.subplots(1, 2, figsize=(16, 6))

    # Plot K-Means
    sns.heatmap(df_kmeans, annot=True, fmt=".0f", cmap="Blues", ax=axes[0], cbar=False)
    axes[0].set_title("Matrice di Confusione: K-Means (K=2)", fontsize=14, pad=15)
    axes[0].set_xlabel("SOC Ground Truth (Incident Grade)", fontsize=12)
    axes[0].set_ylabel("Cluster Predetto", fontsize=12)

    # Plot DBSCAN
    sns.heatmap(df_dbscan, annot=True, fmt=".0f", cmap="Oranges", ax=axes[1], cbar=True)
    axes[1].set_title("Matrice di Confusione: DBSCAN", fontsize=14, pad=15)
    axes[1].set_xlabel("SOC Ground Truth (Incident Grade)", fontsize=12)
    axes[1].set_ylabel("Cluster Predetto", fontsize=12)

    plt.tight_layout()

    img_filename = out_img_path / "Confronto_Matrici_KMeans_vs_DBSCAN.png"
    plt.savefig(img_filename, bbox_inches='tight', dpi=150)
    plt.show()
    print(f"🎨 [DISEGNO] Grafico comparativo esportato in: {img_filename}")

# =============================================================================
# 4. ANALISI FINALE: Risposta per il Professore
# =============================================================================
print("\n" + "="*85)
print(" RELAZIONE FASE 5.2: CONFRONTO K-MEANS vs DBSCAN (AUDIT PROFESSORE)")
print("="*85)
print("Domanda: Le matrici variano tanto o sono simili?")
print("Risposta: VARIANO PROFONDAMENTE.")
print("-" * 85)
print("Giustificazione Analitica:")
print("1. K-Means (Geometria Sferica):")
print("   Forza la divisione dello spazio in gruppi comparabili. Notiamo come")
print("   riesca a segmentare le etichette SOC su due cluster distinti (0 e 1),")
print("   cercando un baricentro matematico.")
print("\n2. DBSCAN (Geometria basata sulla Densità):")
print("   In spazi ad altissima dimensionalità (21 feature numeriche), le distanze")
print("   euclidee convergono. Di conseguenza, DBSCAN tende a classificare la")
print("   stragrande maggioranza dei log come 'Rumore' (Cluster -1) o li collassa")
print("   tutti in un unico macro-cluster (Cluster 0), rendendo la sua matrice")
print("   fortemente sbilanciata e dissimile da quella del K-Means.")
print("=" * 85)
# Out:
# 📥 [INPUT] Caricamento delle matrici di confusione...
# 🧠 [LOGICA] Preparazione dei dati per il confronto visivo...
# 🎨 [DISEGNO] Grafico comparativo esportato in: K:\00_Code\DataScience\Project_ML_Security_Incident_Prediction\notebooks\out\Confronto_Matrici_KMeans_vs_DBSCAN.png
#
# ...
#  RELAZIONE FASE 5.2: CONFRONTO K-MEANS vs DBSCAN (AUDIT PROFESSORE)
# ...
# Domanda: Le matrici variano tanto o sono simili?
# Risposta: VARIANO PROFONDAMENTE.
# -------------------------------------------------------------------------------------
# Giustificazione Analitica:
# 1. K-Means (Geometria Sferica):
#    Forza la divisione dello spazio in gruppi comparabili. Notiamo come
#    riesca a segmentare le etichette SOC su due cluster distinti (0 e 1),
#    cercando un baricentro matematico.
#
# 2. DBSCAN (Geometria basata sulla Densità):
#    In spazi ad altissima dimensionalità (21 feature numeriche), le distanze
#    euclidee convergono. Di conseguenza, DBSCAN tende a classificare la
# ...

# %%
# =============================================================================
# DEFINIZIONE PERCORSO FASE
# =============================================================================


# =============================================================================
# 1. FASE DI INPUT: Quando entra l'input
# =============================================================================
path_profiles_n2 = base_phase_path / "5.1.interpretation.kmeans_n2_profiles.json"
path_soc_confusion = base_phase_path / "5.2.business_evaluation.soc_confusion_matrices.json"
path_recommendations = base_phase_path / "5.4.decision_making.recommendations.json"

with open(path_profiles_n2, 'r', encoding='utf-8') as f:
    cluster_profiles = json.load(f)

with open(path_soc_confusion, 'r', encoding='utf-8') as f:
    soc_eval = json.load(f)

with open(path_recommendations, 'r', encoding='utf-8') as f:
    recommendations = json.load(f)

# =============================================================================
# 2. FASE DI LOGICA: Elaborazione e trasformazione dei dati
# =============================================================================
# Estraiamo i centroidi denormalizzati (profili di business reali)
profile_data = []
for cluster_id, metrics in cluster_profiles.items():
    row = {"Cluster": cluster_id}
    # Assumiamo che dentro metrics ci siano le medie delle feature reali
    for feature, value in metrics.items():
        if isinstance(value, (int, float)):
            row[feature] = round(value, 2)
    profile_data.append(row)

df_business_profiles = pd.DataFrame(profile_data)

# =============================================================================
# 3. FASE DI DISEGNO: Visualizzazione grafica
# =============================================================================
# Usiamo una Heatmap per visualizzare rapidamente cosa caratterizza ogni cluster
plt.figure(figsize=(10, 6))
# Rimuoviamo la colonna 'Cluster' per la heatmap
df_heatmap = df_business_profiles.set_index("Cluster")
# Scaliamo colonna per colonna (solo per la visualizzazione) per evidenziare i contrasti
sns.heatmap(df_heatmap.apply(lambda x: (x-x.mean())/x.std()), annot=df_heatmap.values, cmap="YlGnBu", fmt=".1f", cbar_kws={'label': 'Z-Score Normalizzato'})
plt.title("Fase 5: Heatmap dei Profili di Business (Valori Originali nei riquadri)")
plt.tight_layout()
plt.show()

# =============================================================================
# 4. ANALISI FINALE (Stampa per la presentazione al professore)
# =============================================================================
print("=========================================================================")
print("RELAZIONE FASE 5: VALUTAZIONE DI BUSINESS E RACCOMANDAZIONI")
print("=========================================================================")
print("Identità dei Cluster (Denormalizzata per il Dominio Aziendale):")
display(df_business_profiles)

print("\nAudit di Processo:")
print("- Analisi SOC / Matrice di Confusione applicata ai target di sicurezza/incidente completata.")

print("\nRaccomandazioni Strategiche (Pronti per il Deployment - Fase 6):")
# Stampa sicura in caso le raccomandazioni siano in liste o dizionari
if isinstance(recommendations, dict):
    for k, v in recommendations.items():
        print(f" - {k.upper()}: {v}")
else:
    print(f" - {recommendations}")
print("=========================================================================")
# Out:
# ...
# RELAZIONE FASE 5: VALUTAZIONE DI BUSINESS E RACCOMANDAZIONI
# ...
# Identità dei Cluster (Denormalizzata per il Dominio Aziendale):
#   Cluster   size
# 0       0   6570
# 1       1  23430
# Audit di Processo:
# - Analisi SOC / Matrice di Confusione applicata ai target di sicurezza/incidente completata.
#
# Raccomandazioni Strategiche (Pronti per il Deployment - Fase 6):
#  - OVERALL_RECOMMENDATION: Deployment of unknown is NOT recommended. Address the following barriers before proceeding: ARI threshold not met: 0.000 < 0.050. Clusters show weak alignment with known ground truth.
#  - WINNING_MODEL: unknown
# ...
