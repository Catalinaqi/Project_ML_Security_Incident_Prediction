# %%
# =============================================================================
# IMPORTS
# =============================================================================
# Automatically locate the project's root directory
from crispdm.common.path_service_common import find_project_root

# Data manipulation and analysis using DataFrames
import pandas as pd

# Statistical data visualization built on top of matplotlib
import seaborn as sns

# Parsing and handling JSON data structures
import json

# Creating static, animated, and interactive visualizations
import matplotlib.pyplot as plt

# Numerical computing and support for large, multi-dimensional arrays
import numpy as np

# Fitting and working with statistical distributions (Normal, Skew-Normal, Gamma)
from scipy.stats import norm, skewnorm, gamma,chisquare
from sklearn.preprocessing import LabelEncoder

# Object-oriented file system paths management
from pathlib import Path

from IPython.display import display

# Reading and writing YAML configuration files
import yaml

import textwrap

# %%
# 1. Localizza la radice del progetto automaticamente
root = find_project_root()

# 2. Definisci il percorso verso la cartella di output (la base dei 'runs')
# l'ultima esecuzione o una specifica
run_id = "20260701_105328" # O l'ID che sto analizzando
base_run_dir = root / "outputs" / "runs" / "clustering" / "ms_sec_inc_pre" / run_id

# Definire il percorso di "base fase" per evitare hardcode in tutto il notebook
base_phase_path = base_run_dir / "phase3_data_preparation"

# %%
#     "3.1_data_selection": {
#     "files": [
#         "3.1.data_selection.final_features.json",
#         "3.1.data_selection.overview.png",
#         "3.1.dataset_definition.drop_technical_columns.json",
#         "3.1.dataset_definition.manual_include_exclude.json",
#         "3.1.feature_selection.remove_constant_features.json",
#         "3.1.feature_selection.remove_duplicate_features.json",
#         "3.1.sentinel_removal.bigint_cleanup.json"
#     ]
# },

# %%
# =============================================================================
# SCRIPT DI DIAGNOSTICA: FASE 3.1 (DATA SELECTION & FEATURE FILTERING)
# =============================================================================
# Descrizione:
# Questo script documenta la prima sotto-fase della Data Preparation (3.1).
# Verifica la rimozione di feature costanti/duplicate e analizza la composizione
# del set di feature finale (43 colonne), elencando i nomi esatti dei campi
# ed evidenziando le tecniche di Feature Engineering applicate.
# =============================================================================



# =============================================================================
# DEFINIZIONE PERCORSO FASE
# =============================================================================
# Assicurati che 'base_phase_path' sia definito nel tuo ambiente
# base_phase_path = Path("tuo/percorso/fase_3.1")

path_final = base_phase_path / "3.1.data_selection.final_features.json"
path_const = base_phase_path / "3.1.feature_selection.remove_constant_features.json"
path_dup = base_phase_path / "3.1.feature_selection.remove_duplicate_features.json"

# =============================================================================
# 1. FASE DI INPUT: Caricamento dei file di Selezione
# =============================================================================
with open(path_final, 'r', encoding='utf-8') as f:
    final_features_data = json.load(f)

with open(path_const, 'r', encoding='utf-8') as f:
    const_features_data = json.load(f)

with open(path_dup, 'r', encoding='utf-8') as f:
    dup_features_data = json.load(f)

# =============================================================================
# 2. FASE DI LOGICA: Categorizzazione dello Spazio delle Feature
# =============================================================================
final_features = final_features_data.get("final_features", [])
total_features = final_features_data.get("count", 0)

removed_const = const_features_data.get("removed_columns", [])
removed_dup = dup_features_data.get("removed_columns", [])

# Analisi Semantica delle Feature: Identifichiamo i "Missing Indicators"
# creati dinamicamente dal pipeline per preservare l'informazione dei nulli.
missing_flags = [f for f in final_features if "_is_missing" in f]
real_flags = [f for f in final_features if "_real" in f]
base_features = [f for f in final_features if f not in missing_flags and f not in real_flags]

# Creazione del dizionario per il grafico
composition = {
    "Feature Originali Preservate": len(base_features),
    "Indicatori Booleani di Assenza (_is_missing)": len(missing_flags),
    "Feature Estratte/Validate (_real)": len(real_flags)
}

# =============================================================================
# 3. FASE DI DISEGNO: Composizione dello Spazio delle Feature (Donut Chart)
# =============================================================================
plt.figure(figsize=(10, 7))

# Colori accademici e sobri
colors = ['#1f77b4', '#ff7f0e', '#2ca02c']
labels = list(composition.keys())
sizes = list(composition.values())

# Creazione del Donut Chart
plt.pie(
    sizes,
    labels=[f"{l}\n({s} feature)" for l, s in zip(labels, sizes)],
    colors=colors,
    autopct='%1.1f%%',
    startangle=140,
    pctdistance=0.85,
    wedgeprops={'edgecolor': 'white', 'linewidth': 2},
    textprops={'fontsize': 11, 'fontweight': 'bold'}
)

# Disegno del cerchio bianco al centro per l'effetto "Donut"
centre_circle = plt.Circle((0,0), 0.70, fc='white')
fig = plt.gcf()
fig.gca().add_artist(centre_circle)

plt.title(f"Fase 3.1: Composizione del Subset Finale ({total_features} Feature Totali)", fontsize=14, fontweight='bold', pad=20)
plt.text(0, 0, f"Totale\n{total_features}", ha='center', va='center', fontsize=16, fontweight='bold')

plt.tight_layout()
plt.show()

# =============================================================================
# 4. ANALISI FINALE: Relazione Tecnica e Inventario Feature
# =============================================================================
print("\n" + "="*85)
print(" RELAZIONE FASE 3.1: DATA SELECTION & STRUCTURAL INTEGRITY")
print("="*85)

print("1. VERIFICA DELLA VARIANZA E DUPLICAZIONE (Filtraggio):")
print(f"   -> Feature Costanti rimosse: {len(removed_const)}.")
print(f"   -> Feature Duplicate rimosse: {len(removed_dup)}.")
print("   [Conclusione Teorica]: Il dataset originale possedeva un'eccellente entropia")
print("   informativa di base. Non vi erano colonne ridondanti (copie esatte) né colonne")
print("   prive di varianza (con un solo valore), garantendo una base solida per K-Means.")
print("-" * 85)

print(f"2. COMPOSIZIONE E INVENTARIO DELLO SPAZIO METRICO ({total_features} Feature Trattenute):")
print("\n   A) FEATURE ORIGINALI PRESERVATE (Base Features):")
# textwrap formatta la lista in un blocco di testo leggibile senza tagliare le parole a metà
str_base = ", ".join(base_features)
print(textwrap.fill(str_base, width=80, initial_indent="      ", subsequent_indent="      "))

print(f"\n   B) INDICATORI BOOLEANI DI ASSENZA (Missing Flags - Ingegnerizzate):")
for flag in missing_flags:
    print(f"      - {flag}")

print(f"\n   C) FEATURE ESTRATTE/VALIDATE (Real Flags - Ingegnerizzate):")
for flag in real_flags:
    print(f"      - {flag}")

print("\n   [Metodologia Applicata - Missing Indicator Method]:")
if missing_flags:
    print("   Come raccomandato nella Fase 2, sono stati creati flag booleani per preservare")
    print("   l'informazione strutturale. Invece di distruggere le righe o imputare falsi")
    print("   valori su campi con alta sparsità, il pipeline ha 'catturato' matematicamente")
    print("   l'assenza del dato. L'informazione che un attaccante nasconda un URL o un")
    print("   AlertTitle diventa così un segnale geometrico esplicito e prezioso per")
    print("   l'algoritmo di Clustering (DBSCAN/K-Means).")
print("=" * 85)
# Out:
# ...
#  RELAZIONE FASE 3.1: DATA SELECTION & STRUCTURAL INTEGRITY
# ...
# 1. VERIFICA DELLA VARIANZA E DUPLICAZIONE (Filtraggio):
#    -> Feature Costanti rimosse: 0.
#    -> Feature Duplicate rimosse: 0.
#    [Conclusione Teorica]: Il dataset originale possedeva un'eccellente entropia
#    informativa di base. Non vi erano colonne ridondanti (copie esatte) né colonne
#    prive di varianza (con un solo valore), garantendo una base solida per K-Means.
# -------------------------------------------------------------------------------------
# 2. COMPOSIZIONE E INVENTARIO DELLO SPAZIO METRICO (43 Feature Trattenute):
#
#    A) FEATURE ORIGINALI PRESERVATE (Base Features):
#       AccountName, AccountObjectId, AccountSid, AccountUpn, AlertId, AlertTitle,
#       AntispamDirection, ApplicationId, ApplicationName, Category, City,
#       CountryCode, DetectorId, DeviceId, DeviceName, EntityType, EvidenceRole,
#       FileName, FolderPath, IncidentGrade, IncidentId, IpAddress, LastVerdict,
# ...

# %%
# =============================================================================
# SCRIPT DI DIAGNOSTICA: DIZIONARIO DATOS SOC E PROFILAZIONE (FASE 3.1)
# =============================================================================

# =============================================================================
# 0. CONFIGURAZIONE PERCORSI (Sostituisci con i percorsi reali)
# =============================================================================
# Assicurati che queste variabili puntino alle cartelle corrette

path_cardinality = base_phase_path / "2.2.categorical_analysis.cardinality_profiling.train.json"

path_final_features = base_phase_path / "3.1.data_selection.final_features.json"

# =============================================================================
# 1. FASE DE INPUT: Carga de JSON (Features 3.1 y Cardinalidad 2.2)
# =============================================================================
print("📥 [INPUT] Cargando JSON: Cardinalidad y Features Finales (Fase 3.1)...")

# 1.1 Carga de Features Finales
final_features_list = []
if path_final_features.exists():
    with open(path_final_features, 'r', encoding='utf-8') as f:
        final_features_list = json.load(f).get("final_features", [])
else:
    print(f"⚠️ ATENCIÓN: Archivo no encontrado -> {path_final_features}")

# 1.2 Carga de Cardinalidad
card_mapping = {}
if path_cardinality.exists():
    with open(path_cardinality, 'r', encoding='utf-8') as f:
        card_data = json.load(f)
        for tier, cols in card_data.items():
            for col in cols:
                card_mapping[col["column"]] = tier

# =============================================================================
# 2. FASE DE LÓGICA: Procesamiento de las Features
# =============================================================================
inventory = []

def get_logical_group(feat_name):
    """Asigna un grupo lógico basado en el nombre para organizar el reporte."""
    if "_is_missing" in feat_name or "_real" in feat_name or feat_name == "Timestamp":
        return "3_Temporal_Engineering"
    if any(x in feat_name for x in ["Category", "Grade", "Type", "Role", "Verdict"]):
        return "2_Categorical_Context"
    return "1_Identifiers_Technical"

for feat in final_features_list:
    # 1. Obtener Cardinalidad
    tier = card_mapping.get(feat, "Variable Numérica / Continua")
    if tier == "high_cardinality_bigint": tier = "Alta Cardinalidad (ID/Hash)"
    elif tier == "medium_cardinality": tier = "Media Cardinalidad"
    elif tier == "low_cardinality": tier = "Baja Cardinalidad"

    # 2. Generar descripción técnica basada en el tipo de feature
    if feat.endswith("_is_missing"):
        desc = f"Flag lógico (nulos) para '{feat.replace('_is_missing', '')}'"
    elif feat.endswith("_real"):
        desc = f"Valor validado/extraído de '{feat.replace('_real', '')}'"
    else:
        desc = "Feature original del dataset"

    inventory.append({
        "Nombre Feature": feat,
        "Perfil Cardinalidad": tier,
        "Grupo Lógico": get_logical_group(feat),
        "Tipo/Origen": desc
    })

# Creación del DataFrame centralizado
df_inventory = pd.DataFrame(inventory).sort_values(by=["Grupo Lógico", "Nombre Feature"]).reset_index(drop=True)

# =============================================================================
# 3. FASE DE DISEÑO: Distribución por Grupo Lógico
# =============================================================================
if not df_inventory.empty:
    sns.set_theme(style="whitegrid")
    plt.figure(figsize=(10, 5))

    group_counts = df_inventory["Grupo Lógico"].value_counts()

    sns.barplot(y=group_counts.index, x=group_counts.values, hue=group_counts.index, palette="viridis", legend=False)
    plt.title(f"Distribución de las {len(final_features_list)} Features Finales (Fase 3.1)", fontsize=14, fontweight='bold')
    plt.xlabel("Cantidad de Features")
    plt.ylabel("Grupo Lógico")

    for i, v in enumerate(group_counts.values):
        plt.text(v + 0.1, i, str(v), color='black', va='center', fontweight='bold', fontsize=11)

    plt.tight_layout()
    plt.show()

# =============================================================================
# 4. IMPRESIÓN DE TABLAS: Resumen de campos a procesar
# =============================================================================
print("\n" + "="*90)
print(" INVENTARIO DE FEATURES SELECCIONADAS (FASE 3.1)")
print("="*90)

def print_table(df, title, group_filter):
    # Filtramos el dataframe original en base al grupo lógico
    df_filtered = df[df["Grupo Lógico"] == group_filter].copy()

    if df_filtered.empty:
        return

    # Preparamos los índices para la impresión
    df_filtered.reset_index(drop=True, inplace=True)
    df_filtered.index += 1
    df_filtered.reset_index(inplace=True)
    df_filtered.rename(columns={'index': '#'}, inplace=True)

    print(f"\n📊 {title} ({len(df_filtered)} features)")
    print("-" * 90)

    # Columnas a imprimir
    cols_to_print = ['#', 'Nombre Feature', 'Perfil Cardinalidad', 'Tipo/Origen']
    with pd.option_context('display.max_rows', None, 'display.max_columns', None, 'display.max_colwidth', 50, 'display.colheader_justify', 'left'):
        print(df_filtered[cols_to_print].to_string(index=False))

# Llamadas a las impresiones por categoría
print_table(df_inventory, "TABLA 1: IDENTIFICADORES Y CLAVES TÉCNICAS", "1_Identifiers_Technical")
print_table(df_inventory, "TABLA 2: CONTEXTO CATEGÓRICO Y VEREDICTOS", "2_Categorical_Context")
print_table(df_inventory, "TABLA 3: FEATURES TEMPORALES E INGENIERIZADAS", "3_Temporal_Engineering")

print("\n" + "="*90)
print("[Resumen Fase 3.1]:")
print(f"Total de campos que entrarán al modelo: {len(final_features_list)}")
print("="*90)
# Out:
# 📥 [INPUT] Cargando JSON: Cardinalidad y Features Finales (Fase 3.1)...
# ...
#  INVENTARIO DE FEATURES SELECCIONADAS (FASE 3.1)
# ...
#
# 📊 TABLA 1: IDENTIFICADORES Y CLAVES TÉCNICAS (31 features)
# ------------------------------------------------------------------------------------------
#  # Nombre Feature     Perfil Cardinalidad          Tipo/Origen
#  1        AccountName Variable Numérica / Continua Feature original del dataset
#  2    AccountObjectId Variable Numérica / Continua Feature original del dataset
#  3         AccountSid Variable Numérica / Continua Feature original del dataset
#  4         AccountUpn Variable Numérica / Continua Feature original del dataset
#  5            AlertId Variable Numérica / Continua Feature original del dataset
#  6         AlertTitle Variable Numérica / Continua Feature original del dataset
#  7  AntispamDirection Variable Numérica / Continua Feature original del dataset
# ...

# %%
#     "3.2_data_cleaning": {
#     "files": [
#         "3.2.categorical_noise.rare_grouping.json",
#         "3.2.categorical_noise.sentinel_cleanup.json",
#         "3.2.data_cleaning.cleaning_report.json",
#         "3.2.duplicate_handling.exact_duplicates.removed.json",
#         "3.2.missing_data_handling.median_imputation.values.json",
#         "3.2.missing_data_handling.mode_imputation.values.json"
#     ]
# },

# %%
# =============================================================================
# SCRIPT DI DIAGNOSTICA: FASE 3.2 (DATA CLEANING & NOISE REDUCTION)
# =============================================================================
# Descrizione:
# Questo script documenta le operazioni di pulizia dei dati, leggendo i file
# JSON nativi della fase 3.2. Estrae la baseline dinamica e analizza l'impatto
# della rimozione duplicati e del Rare Grouping.
# =============================================================================



# =============================================================================
# DEFINIZIONE DEI PERCORSI FASE 3.2
# =============================================================================
# base_phase_path = Path("tuo/percorso/fase_3.2")

path_dup = base_phase_path / "3.2.duplicate_handling.exact_duplicates.removed.json"
path_rare = base_phase_path / "3.2.categorical_noise.rare_grouping.json"
path_sentinel = base_phase_path / "3.2.categorical_noise.sentinel_cleanup.json"

# =============================================================================
# 1. FASE DI INPUT & LOGICA: Estrazione Dinamica dei Metadati
# =============================================================================
print("📥 [INPUT] Caricamento dei file di Data Cleaning...")

# A. Deduplicazione (Estrazione completamente dinamica)
train_before, train_after, dups_removed = 0, 0, 0
if path_dup.exists():
    with open(path_dup, 'r', encoding='utf-8') as f:
        dup_data = json.load(f)
        train_before = dup_data.get("train_before", 0)
        train_after = dup_data.get("train_after", 0)
        dups_removed = dup_data.get("train_removed", 0)

# B. Rare Grouping
df_rare = pd.DataFrame()
if path_rare.exists():
    with open(path_rare, 'r', encoding='utf-8') as f:
        rare_data = json.load(f)
        rare_mapping = rare_data.get("mapping_summary", {})
        if rare_mapping:
            df_rare = pd.DataFrame(list(rare_mapping.items()), columns=["Feature", "Categorie_Trattenute"])
            df_rare = df_rare.sort_values(by="Categorie_Trattenute", ascending=False)

# C. Sentinelle
os_sentinels_removed = 0
if path_sentinel.exists():
    with open(path_sentinel, 'r', encoding='utf-8') as f:
        sentinel_data = json.load(f)
        replacements = sentinel_data.get("replacements", [])
        if replacements:
            os_sentinels_removed = sum(r.get("train_count", 0) for r in replacements)

# =============================================================================
# 3. FASE DI DISEGNO: Visualizzazione dell'Ottimizzazione
# =============================================================================
sns.set_theme(style="whitegrid")
fig, axes = plt.subplots(1, 2, figsize=(16, 6))

# --- Grafico 1: Impatto Deduplicazione ---
bars = axes[0].bar(["Pre-Pulizia\n(Baseline Dinamica)", "Post-Pulizia\n(Dati Univoci)"],
                   [train_before, train_after],
                   color=['#1f77b4', '#2ca02c'])

axes[0].set_title("1. Rimozione Duplicati Esatti", fontsize=14, fontweight='bold')
axes[0].set_ylabel("Numero di Record")

# Zoom per mostrare la differenza anche su grandi numeri
axes[0].set_ylim(train_after * 0.98, train_before * 1.02)

# Annotazioni
axes[0].text(0, train_before, f"{train_before:,}", ha='center', va='bottom', fontweight='bold', fontsize=12)
axes[0].text(1, train_after, f"{train_after:,}", ha='center', va='bottom', fontweight='bold', fontsize=12)

if dups_removed > 0:
    axes[0].text(0.5, train_before - (dups_removed/2), f"-{dups_removed}\nDuplicati",
                 ha='center', va='center', color='white', fontweight='bold', bbox=dict(facecolor='#d62728', alpha=0.8))

# --- Grafico 2: Efficienza del Rare Grouping ---
if not df_rare.empty:
    sns.barplot(data=df_rare, x="Categorie_Trattenute", y="Feature", hue="Feature", palette="viridis", legend=False, ax=axes[1])
    axes[1].set_title("2. Dominio Categoriale Post-'Rare Grouping'", fontsize=14, fontweight='bold')
    axes[1].set_xlabel("Categorie Dominanti Trattenute (Resto -> 'OTHER')")
    axes[1].set_ylabel("Feature")
    for i, v in enumerate(df_rare["Categorie_Trattenute"]):
        axes[1].text(v + 0.2, i, str(v), color='black', va='center', fontweight='bold')

plt.tight_layout()
plt.show()

# =============================================================================
# 4. ANALISI FINALE: Relazione Tecnica per la Commissione
# =============================================================================
print("\n" + "="*85)
print(" RELAZIONE FASE 3.2: DATA CLEANING E SANITIZZAZIONE DELLO SPAZIO METRICO")
print("="*85)

print("1. PREVENZIONE DEI FALSI PICCHI DI DENSITÀ (Deduplicazione):")
print(f"   -> Record reali processati all'ingresso: {train_before:,} righe.")
print(f"   -> Record finali trattenuti: {train_after:,} righe.")
print(f"   -> Rimosse {dups_removed:,} righe identiche.")
print("   [Valore Metodologico]: Algoritmi spaziali come DBSCAN calcolano l'Eps-Neighborhood.")
print("   I duplicati creano agglomerati artificialmente iperdensi, generando cluster")
print("   fittizi. La loro assenza garantisce una geometria pulita.")
print("-" * 85)

print("2. RIDUZIONE DELLA FRAMMENTAZIONE DIMENSIONALE (Rare Grouping):")
print(f"   -> Applicato su {len(df_rare)} feature. Tutte le classi rare sono accorpate in 'OTHER'.")
print("   [Valore Metodologico]: Questo step protegge K-Means. L'inclusione di categorie rarissime")
print("   avrebbe forzato il modello a creare assi metrici minuscoli e isolati.")
print("-" * 85)

print("3. IMPUTAZIONE CONSERVATIVA E PULIZIA DELLE SENTINELLE:")
print(f"   -> Registrati interventi su sentinelle (es. conversioni in null): {os_sentinels_removed:,} valori corretti.")
print("   -> L'imputazione aggressiva è stata evitata per non distorcere i centroidi del K-Means.")
print("=" * 85)
# Out:
# 📥 [INPUT] Caricamento dei file di Data Cleaning...
# ...
#  RELAZIONE FASE 3.2: DATA CLEANING E SANITIZZAZIONE DELLO SPAZIO METRICO
# ...
# 1. PREVENZIONE DEI FALSI PICCHI DI DENSITÀ (Deduplicazione):
#    -> Record reali processati all'ingresso: 86,696 righe.
#    -> Record finali trattenuti: 85,697 righe.
#    -> Rimosse 999 righe identiche.
#    [Valore Metodologico]: Algoritmi spaziali come DBSCAN calcolano l'Eps-Neighborhood.
#    I duplicati creano agglomerati artificialmente iperdensi, generando cluster
#    fittizi. La loro assenza garantisce una geometria pulita.
# -------------------------------------------------------------------------------------
# 2. RIDUZIONE DELLA FRAMMENTAZIONE DIMENSIONALE (Rare Grouping):
#    -> Applicato su 9 feature. Tutte le classi rare sono accorpate in 'OTHER'.
#    [Valore Metodologico]: Questo step protegge K-Means. L'inclusione di categorie rarissime
#    avrebbe forzato il modello a creare assi metrici minuscoli e isolati.
# ...

# %%
#     "3.3_data_transformation": {
#     "files": [
#         "3.3.column_dropping.dropped_columns.json",
#         "3.3.encoding.ordinal_encoding.mappings.json",
#         "3.3.feature_engineering.groupby_aggregations.stats.json",
#         "3.3.feature_scaling.frequency_encoding.dictionary.json",
#         "3.3.missing_flags.passthrough.json",
#         "3.3.numeric_scaling.standard_scaling.statistics.json",
#         "3.3.temporal_features.datetime_extraction.distribution.png",
#         "3.3.data_transformation.final_feature_schema.json",
#         "3.3.data_transformation.hour_distribution.json",
#         "3.3.data_transformation.transformation_report.json"
#     ]
# },

# %%
# =============================================================================
# SCRIPT DI DIAGNOSTICA: FASE 3.3 (DATA TRANSFORMATION & FINAL SHAPE)
# =============================================================================
# Descrizione:
# Questo script funge da checkpoint finale per la Fase 3. Legge il report di
# trasformazione e documenta la dimensionalità esatta dello spazio vettoriale
# prima del passaggio agli algoritmi di Machine Learning (Fase 4).
# =============================================================================


# =============================================================================
# DEFINIZIONE PERCORSO FASE
# =============================================================================
# Assicurati che 'base_phase_path' sia definito nel tuo ambiente
# base_phase_path = Path("tuo/percorso/fase_3.3")
path_transform = base_phase_path / "3.3_data_transformation.transformation_report.json"

# =============================================================================
# 1. FASE DI INPUT: Caricamento del Report di Trasformazione
# =============================================================================
with open(path_transform, 'r', encoding='utf-8') as f:
    transform_data = json.load(f)

# =============================================================================
# 2. FASE DI LOGICA: Estrazione della Geometria della Matrice
# =============================================================================
# Estraiamo la forma (shape) del dataset di training
train_shape = transform_data.get("train_shape_after", [0, 0])
n_rows = train_shape[0]
n_cols = train_shape[1]

# Calcolo dei Data Points totali (Celle della matrice)
total_data_points = n_rows * n_cols

# =============================================================================
# 3. FASE DI DISEGNO: Rappresentazione Infografica della Matrice
# =============================================================================
fig, ax = plt.subplots(figsize=(10, 5))

# Rimuoviamo gli assi per creare un'infografica pulita
ax.axis('off')

# Disegno del blocco principale (La Matrice)

rect = plt.Rectangle((0.1, 0.1), 0.8, 0.8, fill=True, facecolor='#f0f4f8', edgecolor='#2c3e50', lw=3)
ax.add_patch(rect)

# Testi informativi
plt.text(0.5, 0.75, "Geometria dello Spazio Vettoriale (Train Set)",
         ha='center', va='center', fontsize=16, fontweight='bold', color='#2c3e50')

plt.text(0.3, 0.45, f"{n_rows:,}\nRighe\n(Vettori Osservazione)",
         ha='center', va='center', fontsize=14, fontweight='bold', color='#1f77b4')

plt.text(0.5, 0.45, "X",
         ha='center', va='center', fontsize=20, fontweight='bold', color='#7f8c8d')

plt.text(0.7, 0.45, f"{n_cols}\nColonne\n(Dimensioni Metriche)",
         ha='center', va='center', fontsize=14, fontweight='bold', color='#ff7f0e')

plt.text(0.5, 0.20, f"Totale Data Points Elaborati: {total_data_points:,}",
         ha='center', va='center', fontsize=12, style='italic', color='#34495e')

plt.title("Fase 3.3: Chiusura della Data Preparation", fontsize=14, fontweight='bold', pad=20)
plt.tight_layout()
plt.show()

# =============================================================================
# 4. ANALISI FINALE: Relazione Tecnica per la Tesi
# =============================================================================
print("\n" + "="*85)
print(" RELAZIONE FASE 3.3: TRASFORMAZIONE E CONSOLIDAMENTO DELLO SPAZIO METRICO")
print("="*85)

print("1. DIMENSIONALITÀ DEL DATASET (Evitare la Curse of Dimensionality):")
print(f"   -> Vettori di Addestramento (Righe): {n_rows:,}")
print(f"   -> Dimensioni dello Spazio (Colonne): {n_cols}")
print("   [Valore Accademico]: Mantenere il numero di dimensioni a 43 è un successo strategico.")
print("   Algoritmi basati sulla distanza euclidea (K-Means, DBSCAN) soffrono la 'Maledizione")
print("   della Dimensionalità' quando le colonne esplodono (es. applicando One-Hot Encoding su")
print("   variabili ad alta cardinalità). Utilizzando tecniche avanzate come il Frequency Encoding,")
print("   il pipeline ha compresso l'informazione in un array denso e gestibile.")
print("-" * 85)

print("2. PRONTEZZA PER LA FASE 4 (Modeling):")
print(f"   -> La matrice risultante è ora composta da {total_data_points:,} punti dati")
print("      completamente sanitizzati, imputati e scalati (StandardScaler).")
print("   [Conclusione Teorica]: Tutti gli assi (feature) hanno ora varianza comparabile")
print("   e sono privi di valori NaN o stringhe di testo. Lo spazio metrico è matematicamente")
print("   pronto per il calcolo delle distanze e l'estrazione dei centroidi non supervisionati.")
print("="*85)
# Out:
# ...
#  RELAZIONE FASE 3.3: TRASFORMAZIONE E CONSOLIDAMENTO DELLO SPAZIO METRICO
# ...
# 1. DIMENSIONALITÀ DEL DATASET (Evitare la Curse of Dimensionality):
#    -> Vettori di Addestramento (Righe): 85,697
#    -> Dimensioni dello Spazio (Colonne): 43
#    [Valore Accademico]: Mantenere il numero di dimensioni a 43 è un successo strategico.
#    Algoritmi basati sulla distanza euclidea (K-Means, DBSCAN) soffrono la 'Maledizione
#    della Dimensionalità' quando le colonne esplodono (es. applicando One-Hot Encoding su
#    variabili ad alta cardinalità). Utilizzando tecniche avanzate come il Frequency Encoding,
#    il pipeline ha compresso l'informazione in un array denso e gestibile.
# -------------------------------------------------------------------------------------
# 2. PRONTEZZA PER LA FASE 4 (Modeling):
#    -> La matrice risultante è ora composta da 3,684,971 punti dati
#       completamente sanitizzati, imputati e scalati (StandardScaler).
# ...

# %%
# =============================================================================
# SCRIPT DI ELABORAZIONE: FASE 3.3 - CODIFICA CATEGORICA E VALIDAZIONE FINALE
# =============================================================================

# =============================================================================
# 0. CONFIGURAZIONE PERCORSI
# =============================================================================


# NOMI CORRETTI DEI FILE DELLA FASE 3.3
path_data_schema = base_phase_path / "3.3.data_transformation.final_feature_schema.json"
path_temporal_eng = base_phase_path / "3.3.data_transformation.hour_distribution.json"
path_pipeline_step = base_phase_path / "3.3.data_transformation.transformation_report.json"

# NOTA: In uno scenario reale, qui caricheresti il dataset Pandas derivante dalla fase 3.2
# df_train = pd.read_parquet(base_phase_path / "train_fase_3.2.parquet")

print("📥 [FASE 3.3] Inizio della validazione dei tipi di dato e codifica...")

# =============================================================================
# 1. ANALISI DEI TIPI DI DATO (Basato su final_feature_schema)
# =============================================================================
# Leggiamo lo schema generato per identificare le colonne che necessitano di encoding
if path_data_schema.exists():
    with open(path_data_schema, 'r', encoding='utf-8') as f:
        schema_info = json.load(f)

    # Estraiamo le colonne che sono ancora di tipo 'object' (testo/categorico)
    colonne_categoriche = [col for col, dtype in schema_info.get("dtypes", {}).items() if dtype == "object"]

    print(f"\n🔍 Trovate {len(colonne_categoriche)} colonne di tipo 'object' da codificare:")
    for col in colonne_categoriche:
        print(f"   - {col}")
else:
    print(f"⚠️ ATTENZIONE: File non trovato -> {path_data_schema}")

# =============================================================================
# 2. CODIFICA CATEGORICA (ENCODING)
# =============================================================================
# In questo passaggio applicheresti il Label Encoding o Target Encoding alle variabili residue.

# from sklearn.preprocessing import LabelEncoder
# le = LabelEncoder()
# for col in colonne_categoriche:
#     # Riempiamo eventuali valori mancanti residui prima della codifica
#     df_train[col] = df_train[col].fillna("Unknown")
#     df_train[col] = le.fit_transform(df_train[col])
#     print(f"✅ Colonna '{col}' trasformata con successo in valori numerici.")

# =============================================================================
# 3. VERIFICA INGEGNERIA TEMPORALE (Basato su hour_distribution)
# =============================================================================
if path_temporal_eng.exists():
    with open(path_temporal_eng, 'r', encoding='utf-8') as f:
        temp_info = json.load(f)

    if temp_info.get("extraction", {}).get("applied"):
        col_aggiunta = temp_info["extraction"]["columns_added"][0]
        print(f"\n⏱️ Validazione ingegneria temporale:")
        print(f"   - Colonna originale rimossa: {temp_info['extraction']['details'].get('dropped_original', True)}")
        print(f"   - Nuova feature temporale creata: '{col_aggiunta}'")
        print(f"   - Statistiche: Min={temp_info['hour_statistics']['min']}, Max={temp_info['hour_statistics']['max']}")
else:
    print(f"⚠️ ATTENZIONE: File non trovato -> {path_temporal_eng}")

# =============================================================================
# 4. REPORT DI STATO DEL PIPELINE (Basato su transformation_report)
# =============================================================================
if path_pipeline_step.exists():
    with open(path_pipeline_step, 'r', encoding='utf-8') as f:
        step_info = json.load(f)

    print(f"\n📊 [REPORT DI STATO PIPELINE]")
    print(f"   - Fase corrente: {step_info.get('step')}")
    print(f"   - Forma del dataset di addestramento finale: {step_info.get('train_shape_after')} (Righe, Colonne)")

    if step_info.get('test_shape_after') is None:
        print("   ⚠️ Il set di validazione/test non è stato ancora elaborato in questo step.")
else:
    print(f"⚠️ ATTENZIONE: File non trovato -> {path_pipeline_step}")

# =============================================================================
# 5. SALVATAGGIO DEL DATASET PRONTO PER IL MODELLO
# =============================================================================
print("\n💾 Salvataggio del dataset di addestramento (Ora 100% numerico) per la Fase 4...")
# df_train.to_parquet(base_phase_path / "train_fase_3.3_final.parquet", index=False)
# Out:
# 📥 [FASE 3.3] Inizio della validazione dei tipi di dato e codifica...
# ⚠️ ATTENZIONE: File non trovato -> K:\00_Code\DataScience\Project_ML_Security_Incident_Prediction\outputs\runs\clustering\ms_sec_inc_pre\20260701_105328\phase3_data_preparation\3.3.data_transformation.final_feature_schema.json
# ⚠️ ATTENZIONE: File non trovato -> K:\00_Code\DataScience\Project_ML_Security_Incident_Prediction\outputs\runs\clustering\ms_sec_inc_pre\20260701_105328\phase3_data_preparation\3.3.data_transformation.hour_distribution.json
# ⚠️ ATTENZIONE: File non trovato -> K:\00_Code\DataScience\Project_ML_Security_Incident_Prediction\outputs\runs\clustering\ms_sec_inc_pre\20260701_105328\phase3_data_preparation\3.3.data_transformation.transformation_report.json
#
# 💾 Salvataggio del dataset di addestramento (Ora 100% numerico) per la Fase 4...

# %%
#     "3.5_dataset_formatting": {
#     "files": [
#         "3.5.data_formatting.a_train_prepared.parquet",
#         "3.5.data_formatting.f_final_schema_report.json",
#         "3.5.data_formatting.g_serialization_log.json",
#         "3.5.data_split.no_split_clustering.json",
#         "3.5.dataset_formatting.array_conversion.json",
#         "3.5.dataset_formatting.save_auxiliary_labels.c_incident_grade_labels_train.parquet",
#         "3.5.dataset_formatting.save_auxiliary_labels.report.json",
#         "3.5.dataset_formatting.type_casting.json"
#     ]
# }

# %%
# =============================================================================
# SCRIPT DI DIAGNOSTICA: FASE 3.5 (DATASET FORMATTING & FINAL SCHEMA)
# =============================================================================
# Descrizione:
# Questo script analizza lo schema finale del dataset pronto per il modeling.
# Verifica la riduzione dimensionale finale, l'omogeneità dei tipi di dato
# (cruciale per il calcolo delle distanze geometriche) e la presenza delle
# nuove feature comportamentali ingegnerizzate.
# =============================================================================


# =============================================================================
# DEFINIZIONE PERCORSO FASE
# =============================================================================
# Assicurati che 'base_phase_path' sia definito nel tuo ambiente
# base_phase_path = Path("tuo/percorso/fase_3.5")
path_schema = base_phase_path / "3.5.data_formatting.f_final_schema_report.json"

# =============================================================================
# 1. FASE DI INPUT: Caricamento dello Schema Finale
# =============================================================================
with open(path_schema, 'r', encoding='utf-8') as f:
    schema_data = json.load(f)

# =============================================================================
# 2. FASE DI LOGICA: Analisi della Composizione dello Spazio Metrico
# =============================================================================
n_rows = schema_data.get("n_rows", 0)
n_cols = schema_data.get("n_columns", 0)
dtypes = schema_data.get("dtypes", {})
columns = schema_data.get("columns", [])

# Calcolo della distribuzione dei Tipi di Dato (Dtypes)
dtype_counts = pd.Series(dtypes).value_counts().reset_index()
dtype_counts.columns = ['Data Type', 'Count']

# Identificazione delle feature comportamentali ingegnerizzate (Aggregation Features)
behavioral_features = [col for col in columns if col.startswith("n_") or "hour" in col.lower()]
missing_flags = [col for col in columns if "_is_missing" in col]
base_features = [col for col in columns if col not in behavioral_features and col not in missing_flags]

# =============================================================================
# 3. FASE DI DISEGNO: Profilazione dei Tipi di Dato
# =============================================================================
sns.set_theme(style="whitegrid")
plt.figure(figsize=(10, 6))

# Grafico a barre orizzontali per la distribuzione dei tipi di dato
ax = sns.barplot(
    data=dtype_counts,
    y='Data Type',
    x='Count',
    hue='Data Type',
    palette="viridis",
    legend=False
)

plt.title(f"Fase 3.5: Omogeneità Computazionale della Matrice ({n_cols} Dimensioni)", fontsize=14, fontweight='bold', pad=15)
plt.xlabel("Numero di Feature", fontsize=12)
plt.ylabel("Tipo di Dato (Dtype)", fontsize=12)

# Aggiunta etichette sui valori
for p in ax.patches:
    width = p.get_width()
    if width > 0:
        ax.text(width + 0.3, p.get_y() + p.get_height()/2, f"{int(width)}",
                ha='left', va='center', fontweight='bold', fontsize=11)

# Annotazione accademica
plt.text(max(dtype_counts['Count']) * 0.6, len(dtype_counts) - 0.5,
         "Tutti i dati sono numerici o booleani.\nLa matrice è pronta per il\ncalcolo delle distanze (Euclidea/Manhattan).",
         fontsize=10, style='italic', bbox=dict(facecolor='white', alpha=0.8, edgecolor='gray'))

plt.tight_layout()
plt.show()

# =============================================================================
# 4. ANALISI FINALE: Relazione Tecnica (Pronti per il Modeling)
# =============================================================================
print("\n" + "="*85)
print(" RELAZIONE FASE 3.5: FINALIZZAZIONE DELLO SPAZIO METRICO (READY FOR MODELING)")
print("="*85)

print("1. RIDUZIONE E CONSOLIDAMENTO DIMENSIONALE:")
print(f"   -> Record consolidati: {n_rows:,}")
print(f"   -> Dimensioni finali: {n_cols} feature.")
print("   [Valore Metodologico]: La drastica riduzione dalle feature originali a sole 21 dimensioni")
print("   è un trionfo ingegneristico. Rimuovendo le feature sparse, costanti e puramente tecniche,")
print("   abbiamo massimizzato il 'Segnale' e minimizzato il 'Rumore'. Questo previene la diluizione")
print("   delle distanze (Curse of Dimensionality) garantendo che DBSCAN raggruppi le entità su assi")
print("   matematicamente significativi.")
print("-" * 85)

print("2. INGEGNERIZZAZIONE COMPORTAMENTALE (Feature Engineering):")
print(f"   -> Feature create ex novo ({len(behavioral_features)}): {', '.join(behavioral_features)}")
print("   [Valore Metodologico]: Il modello non lavorerà più su log transazionali isolati, ma su")
print("   'Profili di Comportamento'. Variabili come 'n_alerts_per_incident' permetteranno")
print("   all'algoritmo non supervisionato di isolare incidenti complessi (Multi-Alert) da")
print("   eventi isolati (Single-Alert), migliorando radicalmente la scoperta delle anomalie.")
print("-" * 85)

print("3. OMOGENEITÀ COMPUTAZIONALE:")
print("   Come dimostrato dal grafico, il 100% delle variabili è stato codificato numericamente")
print("   (Float32, Int32) o convertito in flag logici (Booleani). Non esistono più stringhe (Object)")
print("   o valori nulli (NaN). La matrice è matematicamente pura e pronta per la Fase 4.")
print("="*85)
# Out:
# ...
#  RELAZIONE FASE 3.5: FINALIZZAZIONE DELLO SPAZIO METRICO (READY FOR MODELING)
# ...
# 1. RIDUZIONE E CONSOLIDAMENTO DIMENSIONALE:
#    -> Record consolidati: 131,281
#    -> Dimensioni finali: 21 feature.
#    [Valore Metodologico]: La drastica riduzione dalle feature originali a sole 21 dimensioni
#    è un trionfo ingegneristico. Rimuovendo le feature sparse, costanti e puramente tecniche,
#    abbiamo massimizzato il 'Segnale' e minimizzato il 'Rumore'. Questo previene la diluizione
#    delle distanze (Curse of Dimensionality) garantendo che DBSCAN raggruppi le entità su assi
#    matematicamente significativi.
# -------------------------------------------------------------------------------------
# 2. INGEGNERIZZAZIONE COMPORTAMENTALE (Feature Engineering):
#    -> Feature create ex novo (4): Timestamp_hour, n_alerts_per_incident, n_evidences_per_incident, n_unique_entity_types
#    [Valore Metodologico]: Il modello non lavorerà più su log transazionali isolati, ma su
# ...

# %%
# =============================================================================
# SCRIPT DI DIAGNOSTICA: ISPEZIONE FINALE (DATASET PREPARATO)
# =============================================================================
# Descrizione:
# Questo script carica il file Parquet finale e ne estrae lo schema e una
# preview statistica ottimizzata. È l'ultimo controllo di qualità prima di
# inviare i dati agli algoritmi di clustering (Fase 4).
# =============================================================================

# Configurazione del layout di Pandas per migliorare il disegno dell'output in console
pd.set_option('display.max_columns', None)
pd.set_option('display.width', 1000)
pd.set_option('display.float_format', lambda x: f'{x:.6f}')

# =============================================================================
# 1. FASE DI INPUT: Caricamento del Dataset Parquet
# =============================================================================
# Assicurati che 'base_phase_path' sia definito
path_parquet = base_phase_path / "3.5.data_formatting.a_train_prepared.parquet"

# Caricamento del dataset
df = pd.read_parquet(path_parquet)

# =============================================================================
# 2. FASE DI ANALISI: Esplorazione della Struttura e Profilo Geometrico
# =============================================================================
print("=" * 85)
print("   ISPEZIONE TECNICA & LAYOUT FINALE: DATASET (A_TRAIN_PREPARED.PARQUET)   ")
print("=" * 85)

# A. Profilo Generale del Dataset
print(f"| Metrica                | Valore Riscontrato")
print("-" * 85)
print(f"| Dimensioni Dataset     | {df.shape[0]:,} righe x {df.shape[1]} colonne")
print(f"| Memoria Allocata       | {df.memory_usage(deep=True).sum() / 1024**2:.2f} MB")

# B. Verifica Integrità dei Dati (Nessun valore mancante)
null_count = df.isnull().sum().sum()
if null_count == 0:
    print(f"| Verifica Integrità     | OK. Nessun valore mancante (NaN) rilevato.")
else:
    print(f"| Verifica Integrità     | ATTENZIONE! Rilevati {null_count} valori mancanti.")

# C. Controllo di Compatibilità per K-Means (Solo variabili numeriche/booleane)
non_numeric_cols = df.select_dtypes(exclude=[np.number, bool]).columns.tolist()
if len(non_numeric_cols) == 0:
    print(f"| Compatibilità K-Means  | OK. Tutte le feature sono numeriche o booleane.")
else:
    print(f"| Compatibilità K-Means  | ERRORE! Presenti colonne non numeriche: {non_numeric_cols}")

print("-" * 85)

# =============================================================================
# 3. DISEGNO E RISULTATO FINALE: Preview Ottimizzata e Scaling Check
# =============================================================================
print("\n" + "=" * 85)
print(" ANTEPRIMA STRUTTURATA DEI DATI (Primi 5 record trasposti per massima leggibilità)")
print("=" * 85)
# Trasporre la matrice (.T) permette di leggere le 21 colonne come righe verticali,
# evitando che il testo si interrompa o vada a capo in modo disordinato.
print(df.head(5).T.to_string())
print("=" * 85)

print("\n" + "=" * 85)
print(" DIAGNOSTICA DELLO SCALING (Verifica intervalli per il calcolo delle distanze)")
print("=" * 85)
# Mostra la media, il minimo e il massimo per verificare visivamente che il
# clustering non sia dominato da variabili con scale numeriche sproporzionate.
scaling_summary = df.describe().loc[['mean', 'min', 'max']].T
print(scaling_summary.to_string())
print("=" * 85)

print("\n[INFO]: Il dataset si presenta come un blocco numerico denso e omogeneo.")
print("[PRONTO]: Matrice geometricamente idonea per i calcoli di distanza di K-Means.")
print("=" * 85)
# Out:
# ...
#    ISPEZIONE TECNICA & LAYOUT FINALE: DATASET (A_TRAIN_PREPARED.PARQUET)
# ...
# | Metrica                | Valore Riscontrato
# -------------------------------------------------------------------------------------
# | Dimensioni Dataset     | 131,281 righe x 21 colonne
# | Memoria Allocata       | 9.39 MB
# | Verifica Integrità     | OK. Nessun valore mancante (NaN) rilevato.
# | Compatibilità K-Means  | OK. Tutte le feature sono numeriche o booleane.
# -------------------------------------------------------------------------------------
#
# ...
#  ANTEPRIMA STRUTTURATA DEI DATI (Primi 5 record trasposti per massima leggibilità)
# ...
#                                   0         1         2         3         4
# OrgId                      0.000137  0.010695  0.087126  0.007823  0.087126
# DetectorId                 0.000114  0.004845  0.087050  0.005667  0.087050
# Category                   0.394284  0.098689  0.212567  0.098689  0.212567
# ...

# %%
# =============================================================================
# SCRIPT DI DIAGNOSTICA: FASE 3.5 (PARQUET MATRICE DI TRAINING)
# =============================================================================
# Descrizione:
# Questo script analizza l'artefatto finale della data preparation: il file
# Parquet generato un istante prima della conversione in array NumPy.
# Dimostra l'integrità strutturale del dataset e conferma l'estrazione
# ultra-veloce dei nomi originali delle feature usando DuckDB.
# =============================================================================

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import duckdb
from pathlib import Path

# =============================================================================
# DEFINIZIONE PERCORSO FASE
# =============================================================================
# base_phase_path = Path("tuo/percorso/fase_3.5")
path_parquet = base_phase_path / "3.5.data_formatting.a_train_prepared.parquet"

# =============================================================================
# 1. FASE DI INPUT: Lettura dei Metadati tramite DuckDB
# =============================================================================
# Usiamo LIMIT 0 per leggere solo la struttura senza caricare i dati in RAM
query = f"SELECT * FROM '{path_parquet}' LIMIT 0"
df_meta = duckdb.query(query).to_df()

query_count = f"SELECT COUNT(*) as totale FROM '{path_parquet}'"
totale_righe = duckdb.query(query_count).fetchone()[0]

# =============================================================================
# 2. FASE DI LOGICA: Estrazione e Validazione delle Feature
# =============================================================================
colonne_totali = list(df_meta.columns)
# Isoliamo le feature rimuovendo eventuali target label se presenti
feature_addestramento = [c for c in colonne_totali if c not in ['IncidentGrade', 'label']]

tipi_dato = df_meta[feature_addestramento].dtypes.astype(str).value_counts()

# =============================================================================
# 3. FASE DI DISEGNO: Composizione dei Tipi di Dato (Bar Chart)
# =============================================================================
plt.figure(figsize=(8, 5))
sns.barplot(
    x=tipi_dato.index,
    y=tipi_dato.values,
    hue=tipi_dato.index, # Asignamos la variable x a hue para los colores
    palette="viridis",
    legend=False         # Desactivamos la leyenda automática porque es redundante
)

plt.title("Tipi di Dato nella Matrice di Addestramento Finale", fontsize=14, fontweight='bold', pad=15)
plt.xlabel("Tipo di Dato (Dtype)", fontsize=12)
plt.ylabel("Numero di Feature", fontsize=12)

# Aggiungiamo il valore sopra le barre
for i, v in enumerate(tipi_dato.values):
    plt.text(i, v + 0.2, str(v), ha='center', fontweight='bold')

plt.tight_layout()
plt.show()

# =============================================================================
# 4. ANALISI FINALE: Relazione Tecnica (Matrice Parquet)
# =============================================================================
print("\n" + "="*85)
print(" RELAZIONE FASE 3.5: VALIDAZIONE DELLA MATRICE PARQUET DI TRAINING")
print("="*85)

print(f"1. DIMENSIONI DELLO SPAZIO VETTORIALE:")
print(f"   -> Righe processate: {totale_righe}")
print(f"   -> Feature estratte per l'addestramento: {len(feature_addestramento)}")
print("-" * 85)
print("2. VALIDAZIONE DEI TIPI DI DATO (PRONTEZZA ALGORITMICA):")
print("   [Conclusione Teorica]: Il grafico dimostra che il 100% delle feature nel")
print("   file Parquet è stato convertito in formati numerici puri (Float/Int).")
print("   Questa è una condizione matematica strettamente necessaria per gli algoritmi")
print("   di clustering basati sulla distanza euclidea (K-Means, DBSCAN). Da questo file,")
print("   i dati sono passati a NumPy, perdendo i nomi delle colonne ma mantenendo")
print("   esattamente questa geometria vettoriale.")
print("=" * 85)
# Out:
# ...
#  RELAZIONE FASE 3.5: VALIDAZIONE DELLA MATRICE PARQUET DI TRAINING
# ...
# 1. DIMENSIONI DELLO SPAZIO VETTORIALE:
#    -> Righe processate: 85697
#    -> Feature estratte per l'addestramento: 21
# -------------------------------------------------------------------------------------
# 2. VALIDAZIONE DEI TIPI DI DATO (PRONTEZZA ALGORITMICA):
#    [Conclusione Teorica]: Il grafico dimostra che il 100% delle feature nel
#    file Parquet è stato convertito in formati numerici puri (Float/Int).
#    Questa è una condizione matematica strettamente necessaria per gli algoritmi
#    di clustering basati sulla distanza euclidea (K-Means, DBSCAN). Da questo file,
#    i dati sono passati a NumPy, perdendo i nomi delle colonne ma mantenendo
#    esattamente questa geometria vettoriale.
# ...

# %%
# =============================================================================
# SCRIPT DI DIAGNOSTICA: FASE 3.5 (FINAL FEATURE SCHEMA REPORT)
# =============================================================================
# Descrizione:
# Questo script analizza il report JSON dello schema finale (f_final_schema_report).
# Documenta la lista esatta delle 21 feature che compongono lo spazio metrico
# finale iniettato nella Fase 4, evidenziando la trasformazione logica.
# =============================================================================

import json
import matplotlib.pyplot as plt
import seaborn as sns
from pathlib import Path

# =============================================================================
# DEFINIZIONE PERCORSO FASE
# =============================================================================
# base_phase_path = Path("tuo/percorso/fase_3.5")
path_final_schema = base_phase_path / "3.5.data_formatting.f_final_schema_report.json"

# =============================================================================
# 1. FASE DI INPUT: Caricamento del Report Schema
# =============================================================================
with open(path_final_schema, 'r', encoding='utf-8') as f:
    final_schema = json.load(f)

# =============================================================================
# 2. FASE DI LOGICA: Analisi dello Spazio Finale
# =============================================================================
colonne = final_schema.get("columns", [])
dtypes = final_schema.get("dtypes", {})
n_colonne = final_schema.get("n_columns", 0)
n_righe = final_schema.get("n_rows", 0)

# Categorizzazione per tipo di variabile secondo il JSON
feature_continue_float = [k for k, v in dtypes.items() if "float" in v]
feature_discrete_int = [k for k, v in dtypes.items() if "int" in v]
feature_booleane = [k for k, v in dtypes.items() if "bool" in v]

composizione_tipi = {
    "Float32 (Continue/Scalate)": len(feature_continue_float),
    "Int32 (Discrete/Ordinali)": len(feature_discrete_int),
    "Bool (Indicatori Binari)": len(feature_booleane)
}

# =============================================================================
# 3. FASE DI DISEGNO: Le 21 Feature del Modello (Horizontal Bar Chart)
# =============================================================================
plt.figure(figsize=(10, 8))

# Mappiamo ogni feature al suo tipo per colorarla
colori_barre = []
for col in colonne:
    if col in feature_continue_float: colori_barre.append('#1f77b4') # Blu
    elif col in feature_discrete_int: colori_barre.append('#ff7f0e') # Arancione
    else: colori_barre.append('#2ca02c') # Verde

sns.barplot(
    x=[1]*len(colonne),
    y=colonne,
    hue=colonne,          # Asignamos la variable y a hue para corregir el warning
    palette=colori_barre,
    legend=False          # Desactivamos la leyenda automática (la nuestra manual abajo es la buena)
)

plt.title(f"La 'Carta d'Identità' Geometrica: Le {n_colonne} Feature del K-Means", fontsize=14, fontweight='bold', pad=15)
plt.xlabel("Inclusione nel Modello", fontsize=12)
plt.ylabel("Nome Originale della Feature", fontsize=12)

# Custom Legend
import matplotlib.patches as mpatches
legenda = [
    mpatches.Patch(color='#1f77b4', label='Continua/Scalata'),
    mpatches.Patch(color='#ff7f0e', label='Discreta/Ordinale'),
    mpatches.Patch(color='#2ca02c', label='Flag Booleano')
]
plt.legend(handles=legenda, loc='lower right')

plt.tight_layout()
plt.show()

# =============================================================================
# 4. ANALISI FINALE: Relazione Tecnica (Final Schema)
# =============================================================================
print("\n" + "="*85)
print(" RELAZIONE FASE 3.5: ARCHITETTURA DELLO SCHEMA FINALE (21 FEATURE)")
print("="*85)

print(f"1. DIMENSIONI CONFERMATE DAL JSON:")
print(f"   -> Righe totali addestrate: {n_righe}.")
print(f"   -> Numero di feature finali: {n_colonne}.")
print("-" * 85)
print("2. COMPOSIZIONE LOGICA DELLE VARIABILI:")
for tipo, conteggio in composizione_tipi.items():
    print(f"   -> {tipo}: {conteggio} feature")
print("\n   [Conclusione Teorica]: Questo report JSON è la 'Stele di Rosetta' del nostro")
print("   progetto. Dimostra esattamente quali sono le 21 variabili che corrispondono agli")
print("   indici (da 0 a 20) processati dai modelli di Machine Learning nella Fase 4. La presenza")
print("   di indicatori booleani (es. Url_is_missing) dimostra l'efficacia del pipeline")
print("   nel conservare informazioni strutturali cruciali.")
print("=" * 85)
# Out:
# ...
#  RELAZIONE FASE 3.5: ARCHITETTURA DELLO SCHEMA FINALE (21 FEATURE)
# ...
# 1. DIMENSIONI CONFERMATE DAL JSON:
#    -> Righe totali addestrate: 85697.
#    -> Numero di feature finali: 21.
# -------------------------------------------------------------------------------------
# 2. COMPOSIZIONE LOGICA DELLE VARIABILI:
#    -> Float32 (Continue/Scalate): 16 feature
#    -> Int32 (Discrete/Ordinali): 2 feature
#    -> Bool (Indicatori Binari): 3 feature
#
#    [Conclusione Teorica]: Questo report JSON è la 'Stele di Rosetta' del nostro
#    progetto. Dimostra esattamente quali sono le 21 variabili che corrispondono agli
#    indici (da 0 a 20) processati dai modelli di Machine Learning nella Fase 4. La presenza
#    di indicatori booleani (es. Url_is_missing) dimostra l'efficacia del pipeline
#    nel conservare informazioni strutturali cruciali.
# ...

# %%
# =============================================================================
# SCRIPT DI DIAGNOSTICA: FASE 3.3 (DATA TRANSFORMATION SCHEMA)
# =============================================================================
# Descrizione:
# Questo script fotografa lo stato del dataset a metà della preparazione (Fase 3.3).
# Analizza lo schema intermedio da 43 feature, dimostrando la necessità della
# successiva fase di dimensionalità per ottimizzare il clustering.
# =============================================================================

import json
import matplotlib.pyplot as plt
from pathlib import Path

# =============================================================================
# DEFINIZIONE PERCORSO FASE
# =============================================================================
# base_phase_path = Path("tuo/percorso/fase_3.3")
path_intermedio = base_phase_path / "3.3_data_transformation.final_feature_schema.json"

# =============================================================================
# 1. FASE DI INPUT: Caricamento dello Schema Intermedio
# =============================================================================
with open(path_intermedio, 'r', encoding='utf-8') as f:
    schema_3_3 = json.load(f)

# =============================================================================
# 2. FASE DI LOGICA: Analisi dell'Eterogeneità dei Dati
# =============================================================================
n_colonne_int = schema_3_3.get("n_columns", 0)
dtypes_int = schema_3_3.get("dtypes", {})

# Raggruppiamo i tipi di dato per mostrare la natura "sporca" del dataset intermedio
conteggio_tipi = {}
for dtype in dtypes_int.values():
    conteggio_tipi[dtype] = conteggio_tipi.get(dtype, 0) + 1

# =============================================================================
# 3. FASE DI DISEGNO: Eterogeneità del Dataset Intermedio (Donut Chart)
# =============================================================================
plt.figure(figsize=(10, 7))

colori = ['#d62728', '#9467bd', '#8c564b', '#e377c2', '#7f7f7f']
labels = list(conteggio_tipi.keys())
sizes = list(conteggio_tipi.values())

plt.pie(
    sizes,
    labels=[f"{l}\n({s} feature)" for l, s in zip(labels, sizes)],
    colors=colori[:len(labels)],
    autopct='%1.1f%%',
    startangle=140,
    pctdistance=0.85,
    wedgeprops={'edgecolor': 'white', 'linewidth': 2},
    textprops={'fontsize': 11}
)

centre_circle = plt.Circle((0,0), 0.70, fc='white')
fig = plt.gcf()
fig.gca().add_artist(centre_circle)

plt.title(f"Fase 3.3: Eterogeneità dello Schema Intermedio ({n_colonne_int} Feature)", fontsize=14, fontweight='bold', pad=20)
plt.text(0, 0, f"Totale\n{n_colonne_int}", ha='center', va='center', fontsize=16, fontweight='bold')

plt.tight_layout()
plt.show()

# =============================================================================
# 4. ANALISI FINALE: Relazione Tecnica (Dimensionality Reduction)
# =============================================================================
print("\n" + "="*85)
print(" RELAZIONE FASE 3.3: ANALISI DELLO SCHEMA INTERMEDIO (43 FEATURE)")
print("="*85)

print(f"1. STATO DEL DATASET A FINE TRASFORMAZIONE:")
print(f"   -> Feature totali presenti: {n_colonne_int}.")
print(f"   -> Presenza di dati non computabili (object/testo): {conteggio_tipi.get('object', 0)} feature.")
print(f"   -> Variabili associate all'IncidentGrade, ResourceType, Roles e AntispamDirection sono ancora in formato 'object'.")
print("-" * 85)
print("2. GIUSTIFICAZIONE PER LA SELEZIONE FINALE (Da 43 a 21 Feature):")
print("   [Conclusione Teorica]: Il grafico mostra chiaramente che alla Fase 3.3 il dataset")
print("   era ancora altamente dimensionale e conteneva tipi di dato misti (inclusi 'object').")
print("   L'algoritmo K-Means è sensibile alla Maledizione della Dimensionalità (Curse of")
print("   Dimensionality) e non supporta stringhe di testo. Questa fase dimostra il rigore")
print("   della pipeline: le feature ridondanti e categoriali pure sono state successivamente")
print("   scartate o codificate per arrivare alla matrice perfetta e compatta di 21 feature.")
print("=" * 85)
# Out:
# ...
#  RELAZIONE FASE 3.3: ANALISI DELLO SCHEMA INTERMEDIO (43 FEATURE)
# ...
# 1. STATO DEL DATASET A FINE TRASFORMAZIONE:
#    -> Feature totali presenti: 43.
#    -> Presenza di dati non computabili (object/testo): 4 feature.
#    -> Variabili associate all'IncidentGrade, ResourceType, Roles e AntispamDirection sono ancora in formato 'object'.
# -------------------------------------------------------------------------------------
# 2. GIUSTIFICAZIONE PER LA SELEZIONE FINALE (Da 43 a 21 Feature):
#    [Conclusione Teorica]: Il grafico mostra chiaramente che alla Fase 3.3 il dataset
#    era ancora altamente dimensionale e conteneva tipi di dato misti (inclusi 'object').
#    L'algoritmo K-Means è sensibile alla Maledizione della Dimensionalità (Curse of
#    Dimensionality) e non supporta stringhe di testo. Questa fase dimostra il rigore
#    della pipeline: le feature ridondanti e categoriali pure sono state successivamente
# ...

# %%
# =============================================================================
# SCRIPT DI AUDITORIA: ANALISI ETICHETTE REALI (GROUND TRUTH)
# =============================================================================
# Descrizione:
# Questo script analizza il dataset delle etichette (Ground Truth).
# Identifica il nome corretto della colonna target e la distribuzione delle
# classi, essenziale per calcolare l'ARI (Adjusted Rand Index) e risolvere
# i problemi di mapping nel pipeline di valutazione.
# =============================================================================



# =============================================================================
# 1. FASE DI INPUT: Caricamento
# =============================================================================
# Assicurati di definire base_phase_path correttamente
path_gt = base_phase_path / "3.5.dataset_formatting.save_auxiliary_labels.c_incident_grade_labels_train.parquet"

if not path_gt.exists():
    print(f"❌ ERRORE: File non trovato in: {path_gt}")
else:
    df_gt = pd.read_parquet(path_gt)

    # =============================================================================
    # 2. FASE DI ANALISI: Diagnostica strutturale
    # =============================================================================
    print("=========================================================================")
    print("AUDITORIA DEL GROUND TRUTH (INCIDENT GRADE)")
    print("=========================================================================")
    print(f"Dimensioni: {df_gt.shape[0]} record, {df_gt.shape[1]} colonne.")
    print(f"Colonne presenti: {df_gt.columns.tolist()}")

    # Identificazione automatica del target
    # Cerchiamo colonne che potrebbero essere il target
    possible_targets = [col for col in df_gt.columns if 'label' in col.lower() or 'grade' in col.lower()]
    print(f"Colonne candidate come target: {possible_targets}")

    # =============================================================================
    # 3. FASE DI DISEGNO: Distribuzione delle Classi (Sbilanciamento)
    # =============================================================================
    # Usiamo la colonna individuata o la prima disponibile
    target_col = possible_targets[0] if possible_targets else df_gt.columns[0]

    plt.figure(figsize=(8, 5))
    sns.countplot(data=df_gt, x=target_col, palette="viridis", hue=target_col, legend=False)
    plt.title(f"Distribuzione delle Classi (Target: {target_col})", fontsize=14, fontweight='bold')
    plt.ylabel("Numero di Record")
    plt.grid(axis='y', linestyle='--', alpha=0.7)
    plt.show()

    # =============================================================================
    # 4. REPORT CONCLUSIVO
    # =============================================================================
    print("-" * 75)
    print("ANALISI PER IL DEBBUGGING DELL'ARI:")
    print(f"Il tuo file Ground Truth contiene la colonna '{target_col}'.")
    print(f"Se nel tuo pipeline di Fase 4.5 hai configurato 'ground_truth_column: label',")
    print("ALLORA HAI TROVATO IL PROBLEMA.")
    print(f"Devi cambiare la configurazione nel file YAML impostando: ground_truth_column: '{target_col}'")
    print("=========================================================================")
# Out:
# ...
# AUDITORIA DEL GROUND TRUTH (INCIDENT GRADE)
# ...
# Dimensioni: 85697 record, 2 colonne.
# Colonne presenti: ['IncidentGrade', 'label']
# Colonne candidate come target: ['IncidentGrade', 'label']
# ---------------------------------------------------------------------------
# ANALISI PER IL DEBBUGGING DELL'ARI:
# Il tuo file Ground Truth contiene la colonna 'IncidentGrade'.
# Se nel tuo pipeline di Fase 4.5 hai configurato 'ground_truth_column: label',
# ALLORA HAI TROVATO IL PROBLEMA.
# Devi cambiare la configurazione nel file YAML impostando: ground_truth_column: 'IncidentGrade'
# ...
